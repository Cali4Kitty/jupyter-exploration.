# %% [markdown]
# <a href="https://colab.research.google.com/github/Cali4Kitty/jupyter-exploration./blob/main/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# My first markdown cell in Jupyter.

# %%
print("Hello, World!")
# Out:
# Hello, World!
